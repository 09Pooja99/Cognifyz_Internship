# %% [markdown]
# Level 1
#
# Task4: Online Delivery
#
# Determine the percentage of restaurants
# that offer online delivery.
#
# Compare the average ratings of restaurants
# with and without online delivery.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
path = ('/content/drive/MyDrive/Cognifyztechnologies_Internship/dataset .csv')
df= pd.read_csv(path)
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
online_delivery = df['Has Online delivery'].count()
table_booking = df['Has Table booking'].count()
print(online_delivery)
print(table_booking)
total_delivery = (online_delivery + table_booking)
print(total_delivery)
percentage_online_delivery = online_delivery / total_delivery * 100
print(percentage_online_delivery)
# Out:
# 9551
# 9551
# 19102
# 50.0

# %%
average_rating_with_online_delivery = restaurant_with_online_delivery['Aggregate rating'].mean()
average_rating_without_online_delivery = restaurant_without_online_delivery['Aggregate rating'].mean()
print('average rating with online delivery is:',  average_rating_with_online_delivery)
print('average rating without online delivery is:', average_rating_without_online_delivery)
# Out:
# average rating with online delivery is: 3.2488372093023257
# average rating without online delivery is: 2.465295774647887
