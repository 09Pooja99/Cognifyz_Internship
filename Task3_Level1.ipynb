# %% [markdown]
# Level 1
#
#
# ---
#
# Task3: Price Range Distribution
#
# Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants.
#
# Calculate the percentage of restaurants in each price range category.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path = ('/content/drive/MyDrive/Cognifyztechnologies_Internship/dataset .csv')
df = pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
rn_pr = df[['Restaurant Name','Price range']]
restaurant_count = rn_pr.groupby('Price range').count()
print(restaurant_count)
# Out:
#              Restaurant Name
# Price range
# 1                       4444
# 2                       3113
# 3                       1408
# 4                        586

# %%
color = ('green', 'blue','yellow', 'orange')
plt.bar(restaurant_count.index, restaurant_count['Restaurant Name'], color=color)
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')
plt.title('Price Range Distribution')

plt.show()

# %% [markdown]
# Calculate the percentage of restaurants in each price range category.

# %%
rn_pr = df[['Restaurant Name','Price range']]
total_restaurant_count = rn_pr['Price range'].count()
percentage_count = (restaurant_count / total_restaurant_count) * 100
print(percentage_count)
# Out:
#              Restaurant Name
# Price range
# 1                  46.529159
# 2                  32.593446
# 3                  14.741912
# 4                   6.135483

# %%
plt.pie(percentage_count['Restaurant Name'], labels=percentage_count.index, autopct='%1.2f%%')
plt.title('Price Range Distribution')
plt.show()
